# %%
import numpy as np
import pandas as pd

import json
import pickle
import requests

# %%
url = "https://wordcloudapp.herokuapp.com/api"

# %%
data = json.dumps({"business_id": "Y5eFSPCS_c3k6ueiCRj6dA"})

# %%
print(data)
# Out:
# {"business_id": "Y5eFSPCS_c3k6ueiCRj6dA"}

# %%
send = requests.post(url, data)

# %%
send
# Out:
# <Response [200]>

# %%
reviews = pd.read_csv('reviews.csv')

# %%
reviews.columns
# Out:
# Index(['business_id', 'cool', 'date_time', 'funny', 'review_id', 'star_review',
#        'text', 'useful', 'user_id', 'tokens', 'date'],
#       dtype='object')

# %%
bus = pd.read_csv('businessaggdatav2.csv')

# %%
bus.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'business_id', 'address', 'city',
#        'is_open', 'latitude', 'longitude', 'name', 'review_count', 'stars',
#        'state', 'categories', 'percentile', 'competitors', 'postalcode',
#        'bestinsector', 'star_review1.0', 'star_review2.0', 'star_review3.0',
#        'star_review4.0', 'star_review5.0', 'numreviews2009', 'numreviews2010',
#        'numreviews2011', 'numreviews2012', 'numreviews2013', 'numreviews2014',
#        'numreviews2015', 'numreviews2016', 'numreviews2017', 'numreviews2018',
#        'average_stars_over_time', 'top_pos_neg_noun_chunks'],
#       dtype='object')

# %%
df = reviews.merge(bus, how='inner', on='business_id')

# %%
df['name'].tolist()
# Out:
# ['Ramen KoBo',
#  'Ramen KoBo',
#  'Centennial Leasing & Sales',
#  'Rosewood Chinese Cuisine',
#  'The Cutting Board',
#  'Hilton Madison',
#  'North Restaurant- Shomal',
#  'Baby Loves Tacos',
#  'Centurion',
#  'Walgreens',
#  'Tuscany Gardens',
#  'Cafe Rumba',
#  'Egg Works',
#  'Zigarren',
#  "Lo-Lo's Chicken & Waffles",
#  'Thaiphon',
#  'Staybridge Suites Charlotte Ballantyne',
#  'Flex AZ',
#  'Jaipur Junction',
#  'Arizona Animal Wellness Center',
#  "Ken Stewart's Tre Belle",
#  'Greenwood Subway Station',
#  'Paradise Bakery & Cafe',
#  'Four Peaks Brewing',
#  'Four Peaks Brewing',
#  'Four Peaks Brewing',
#  'Havana Grill',
#  "Hussong's Cantina Las Vegas",
#  'Kaba Curry',
#  'Dr Robert Kistner',
#  'Jamba Juice',
#  'Taco Bell',
#  'Outback Steakhouse',
#  "Men's Wearhouse",
#  "Sullivan's Steakhouse",
#  'SEA: The Thai Experience',
#  'Buca di Beppo Italian Restaurant',
#  'Hikari',
#  'Samazing Skin Services',
#  'Bow Valley Ranche Restaurant',
#  'Ahipoki - Phoenix',
#  "Balzac's Coffee Roastery",
#  'Cracker Barrel Old Country Store',
#  'Cracker Barrel Old Country Store',
#  'Cracker Barrel Old Country Store',
#  'Mucha Lucha Taco Shop',
#  'Midwood Smokehouse',
#  "Blu Pool at Bally's",
#  'Power MMA & Fitness',
#  'Sunset Auto Imports Service',
#  'Clothes Mentor - Avondale',
#  'Open Sesame Market',
#  "Alice Fazooli's",
#  'Zero Below',
#  'Davide Bakery and Cafe',
#  'East End Brewing Company',
#  'Pretty Nails',
#  'Saints & Scissors Salon',
#  'Honest-1 Auto Care',
#  'Dim Sum Cafe',
#  'Copper Blues Rock Pub & Kitchen - Phoenix',
#  'Il Pizzaiolo',
#  'Sweet Tomatoes',
#  'Tequileria Grille',
#  'Paris Las Vegas Hotel & Casino',
#  'Millie Creperie',
#  'El Rincon Mexican Grill Wadsworth',
#  'Carload Food Market',
#  'The Chicken Shack',
#  'The Friar: A Firkin Pub',
#  'Made In Mexico',
#  'Ruchi Vegetarian South Indian Cuisine',
#  'Mor Furniture for Less',
#  'Pier W',
#  'Al-Hana',
#  "Macayo's Mexican Table",
#  'Oishii Bento',
#  'Sun Asian Kitchen',
#  'Full Circle Auto Wash',
#  'China City Super Buffet',
#  "Tom's Urban",
#  'The Greene House',
#  "McAlister's Deli",
#  'Mi Casa Grill Cantina',
#  'Goods & Provisions',
#  'La Fiesta Mexican Restaurant',
#  "Maxim's Café & Patisserie",
#  'Polished Nails & Spa',
#  'Veganbites',
#  'Pong Pong Restaurant',
#  'Ka Chi',
#  'Native Grill & Wings',
#  'Road Runner Sports',
#  'Square Cafe',
#  "McDonald's",
#  'Olives Mediterranean Grill',
#  'Gangnam Asian BBQ Dining',
#  'Flamingo Banquet Hall',
#  'Little India',
#  'The Casual Pint - Ocotillo',
#  'Oh Dumplings!',
#  "Preston's Steakhouse",
#  "Dunkin' Donuts",
#  'SOL Mexican Cocina',
#  'The UPS Store',
#  'Einstein Cafe & Pub',
#  'Shepherd School of Language',
#  "Casey Moore's Oyster House",
#  'Desert Adventures',
#  'Vegas Noodle House',
#  'El Chorro',
#  'El Chorro',
#  "Sherry's Nails & Spa",
#  'Fired Pie',
#  'Native Grill & Wings',
#  "Tommy's Fairview Tavern",
#  'The Peppermill Restaurant & Fireside Lounge',
#  'The Peppermill Restaurant & Fireside Lounge',
#  'Even Stevens Sandwiches',
#  'Evel Pie',
#  "Nelia's Smokehouse",
#  'Tuscany Suites & Casino',
#  'Sumac',
#  'Salt & Lime Modern Mexican Grill',
#  'Stratosphere',
#  'Aoyama Sushi Restaurant',
#  'Welcome Diner',
#  'Mood Swings Salon',
#  'Jenni Pho',
#  'My Pigsty Furniture Warehouse',
#  'Panera Bread',
#  'All My Sons Moving & Storage',
#  "Denny's",
#  'RideNow Powersports Surprise',
#  'Lucidi Distilling',
#  'TAO Nightclub',
#  'Angry Crab Shack',
#  'The Tint Shop',
#  'Firefly',
#  'ARIA Resort & Casino',
#  "Ronald's Donuts",
#  'Alphagraphics',
#  'Dollar Tree',
#  'The Bank',
#  'Tacos El Gordo',
#  "Flancer's",
#  "Grampa's Pizzeria",
#  "Raul's Original",
#  'Sit Means Sit',
#  'The Chill Frozen Yogurt',
#  'Squaw Peak Animal Hospital',
#  'Buffalo Wild Wings',
#  'Macleod Trail World Health',
#  'Spice Kitchen + Bar',
#  'Bar 145 - Avon',
#  "Gordon Ramsay Hell's Kitchen",
#  'Gaucho Parrilla Argentina',
#  'Foothills Sports Medicine Physical Therapy',
#  'Graduate Tempe',
#  'Agave - The Arizona Spa',
#  'Kim Foo',
#  'Fascinations',
#  'Mountain Shadows',
#  'Los Favoritos Taco Shop',
#  'Katchakid',
#  'Colonial Eatery',
#  'Starbucks',
#  'Cheba Hut Toasted Subs',
#  'Cutters Document Destruction',
#  'The Spa at Encore',
#  'Pho Thanh Huong',
#  'BLT Steak, Scottsdale',
#  'Off The Strip at the LINQ',
#  'Kiyomizu Restaurant',
#  'Ethel M Chocolate',
#  'Ethel M Chocolate',
#  'Pier 1',
#  'First Watch',
#  'Heritage at Deer Valley',
#  'Starbucks',
#  'Lemongrass Café',
#  'Kaiju',
#  'Kaiju',
#  'Lillian Lottie Couture',
#  'Playa Papagayos',
#  'Bighorn Law',
#  'Popeyes Louisiana Kitchen',
#  "Cam's Auto Service",
#  'Holsteins',
#  'Holsteins',
#  'Herbs & Rye',
#  'Brûlerie St-Denis',
#  'SkyBar',
#  'The Roomstore',
#  'Galaxy Cannery Theatre',
#  'Excalibur Hotel',
#  'Carnival World & Seafood Buffet',
#  'Carnival World & Seafood Buffet',
#  'Rehab Beach Club',
#  'The Platinum Spray Tan',
#  'Native Grill & Wings',
#  'Loving Hut',
#  'Crepe Studio Bistro',
#  'Sushi Roku',
#  'Mesa Modern Dentistry and Orthodontics',
#  "Mermaid's Casino",
#  'Holiday Inn Hotel & Suites Phoenix Airport North',
#  'Il Fornaio',
#  'The Bandit Coffee Group',
#  'Thai Patio',
#  'Noodlecat',
#  'Even Stevens Sandwiches',
#  "Nature's Pet Las Vegas",
#  'Saving Gigi',
#  'Cornish Pasty',
#  'Little Luxuries',
#  'Mr Clean Carpet Care',
#  'Dean & DeLuca',
#  'Rise & Shine a Steak & Egg Place',
#  "George's Kitchen",
#  'Canaletto',
#  'Canaletto',
#  'LA Fitness',
#  'Panda Express',
#  'Nakama Sushi Restaurant & Lounge',
#  'LVH - Las Vegas Hotel & Casino',
#  'Simon Restaurant and Lounge',
#  'Omni William Penn Hotel',
#  'Omni William Penn Hotel',
#  'The Yarn Guy',
#  'Hooters Casino Hotel Las Vegas',
#  'Volvo of Las Vegas',
#  'Chica',
#  'Lux Central',
#  'M&M Soul Food Cafe',
#  'POTs',
#  'W Montréal',
#  'Studio VaVaVoom',
#  'Safelite AutoGlass',
#  'Venetian Casino Grazie Club Gold Room',
#  "Mickey's Tavern",
#  'Manzel Auto Service',
#  'Pho Xua',
#  "Connolly's On Fifth",
#  'Aces High Party Rentals',
#  'MIX',
#  'Hakkasan Nightclub',
#  'Hakkasan Nightclub',
#  "StonePepper's Grill",
#  'Kibo Sushi House',
#  "Sammy's Deli & Neighborhood Pub",
#  "Sammy's Deli & Neighborhood Pub",
#  'Kimchi Korea House',
#  "Lucky's Cafe",
#  "Lucky's Cafe",
#  'SkyView YMCA',
#  'Bloomfield Bridge Tavern',
#  'Citrus Restaurant and Lounge',
#  'Aptive',
#  'Angels Trumpet Ale House',
#  "sweetDee's bakeshop",
#  "Diablo's Cantina",
#  'Eyebrows 4 Us',
#  'Shake Shack',
#  "Fausto's Mexican Grill",
#  'Chen & Wok',
#  'Stratosphere Thrills',
#  'Circle K',
#  'Pho Tien Thanh',
#  "Braddah's Island Style",
#  'Koi Restaurant',
#  'Koi Restaurant',
#  'Bacchanal Buffet',
#  'Mashiso Asian Grille',
#  'The UPS Store',
#  'Diamond Cabaret',
#  'Saffron Patch',
#  'Eis Cream Cafe',
#  'Pokito',
#  'Trattoria Reggiano',
#  'Bouchon Bakery at the Venetian Theater',
#  "Rooster's Uptown",
#  'Momocho',
#  'Milagro Grill',
#  'Primanti Bros',
#  'Elysian Nail Bar',
#  'JEWEL Nightclub',
#  'India Masala',
#  'Phoenix Landscaping & Pools',
#  'Luxor Hotel and Casino Las Vegas',
#  'Dutch Bros Coffee',
#  'Marquee Nightclub & Dayclub',
#  'Del Friscos',
#  "Mom & Pop's Bagel & Bakery",
#  'Chicago Brewing Company',
#  'LOOK Style Society',
#  'Al Hamra',
#  'Arizona Wilderness Brewing',
#  'The Standard',
#  "Guido's Bar & Grill",
#  "Roberto's Tacos",
#  "Hog's Heaven BBQ",
#  'Meineke Car Care Center',
#  'Pho Ngoc Yen Restaurant',
#  'Sprint Store by Connectivity Source',
#  'Summit Roofing',
#  'Golden Nugget Buffet',
#  'All Spray No Rayz Tanning',
#  "Slyman's Tavern",
#  'Botero',
#  'LOL Kids Club',
#  'Arizona Hypnotherapy Clinic',
#  'Famous Hair',
#  'Alta Vista Veterinary Hospital',
#  'Arizona Exposition & State Fair',
#  'Texas Roadhouse',
#  'Elite Paw Spa',
#  'Las Palmas Cantina',
#  'Café Zupas',
#  'Door Creek Church',
#  'Express Marble and Granite',
#  'Smokin Fins',
#  'The Canadian Brewhouse',
#  "Fuzzy's Taco Shop",
#  'Grazie Ristorante',
#  'Affordable Dentures & Implants',
#  'Pizza Marsala',
#  'I-Migoo',
#  'Trattoria Mercatto',
#  'The Buffet at ARIA',
#  'Etsu Restaurant',
#  'Craig Ranch Regional Park',
#  'Papa Primoz',
#  'Umiya Sushi',
#  'The Cracked Egg',
#  'Sibling Revelry Brewing',
#  'Daily Dose',
#  "Domino's Pizza",
#  "Lee's Sandwiches",
#  'Ms MacNCheese',
#  'Ronald M Glick, DO',
#  "BJ's Restaurant & Brewhouse",
#  'Roma Deli II and Wine Shop',
#  'Amore Taste of Chicago',
#  "Nicky's Thai Kitchen",
#  'Smashburger',
#  'Cucina di Vita',
#  'Enso Asian Bistro & Sushi Bar',
#  'Atkins Circle',
#  'Forefathers Cheesesteaks',
#  'Cabo Mexican Restaurant',
#  'Aroma Espresso Bar',
#  'Toronto Bicycle Tours',
#  'Hungry For Time',
#  'Dimmi Bar & Trattoria',
#  'China Ginger',
#  'Katsuya',
#  'Nourish',
#  'Carpe Diem',
#  'Berkeley Running',
#  'North Italia',
#  'Tin Tin',
#  'La Carnita',
#  'Jefferson St Deli',
#  "Chelsea's Kitchen",
#  'Air Conditioning Of Arizona',
#  'La-Z-Boy Furniture Galleries',
#  'Embassy Suites Phoenix Scottsdale',
#  'The Collective Hair Studio',
#  'Tokyo House',
#  'Queen City Q',
#  'Happy Dog',
#  'WinCo Foods',
#  'Bannock',
#  'PetSmart',
#  'Auto Solutions',
#  "Emeril's New Orleans Fish House",
#  'SanTan Village',
#  "Don G's Pizzeria",
#  "KGB: Kerry's Gourmet Burgers",
#  'Green Valley Ranch Resort & Spa',
#  'Desert Wireless',
#  'Big O Tires',
#  "Sarah's Vineyard",
#  'Yama Sushi',
#  'Union Station Go Bus Terminal',
#  'Bei',
#  'Firehouse',
#  'Soba',
#  'Angels Carpet Care',
#  'Slickables',
#  'AAA - South End',
#  'The Pub Beachwood',
#  'Solutions Rubiks',
#  "Trader Vic's",
#  "Rustler's Rooste",
#  'Gadzooks Enchiladas & Soup',
#  'EōS Fitness - Las Vegas: Aliante/Centennial Pkwy',
#  'AutoZone',
#  'Bar 11',
#  'Reposado Bar & Lounge',
#  "Guy Fieri's Vegas Kitchen & Bar",
#  "Guy Fieri's Vegas Kitchen & Bar",
#  'Cold Stone Creamery',
#  'Viet Kitchen',
#  'Las Vegas South Premium Outlets',
#  'San Carlos Bay Seafood Restaurant',
#  'Voila French Bistro and Wine Bar',
#  'To-ne Sushi',
#  'Sakana',
#  'The Palm Las Vegas',
#  'Greek Palace Mediterranean',
#  'La Hacienda',
#  'Krav Food Truck',
#  'Nonna Urban Eatery',
#  'Musée des Beaux-Arts de Montréal',
#  'The Clarendon Hotel',
#  "Martorano's",
#  "Hal's Bar and Grill",
#  'Poke Wave',
#  'Poke Wave',
#  'Rose Tea Cafe',
#  "Chola's",
#  'Sporting Life Bar',
#  'The Palazzo Las Vegas',
#  'Desert Tumbling',
#  'Rainbow Dental Care',
#  'The Whining Pig- Arcadia',
#  '9 Bars',
#  'Wasabi Japanese Steak House',
#  'Mesa Park',
#  'Liverpool House',
#  "Children's Museum of Phoenix",
#  'Scotland Yard',
#  "Julia's Mesquite Mexican and Burgers",
#  'McKnight Veterinary Hospital',
#  'Platinum Auto Makeover',
#  'Imperial Health Spa',
#  'Imperial Health Spa',
#  "Eisenbergs' Fine Furniture",
#  'Le Poké Bar',
#  'Public Storage',
#  'Melt Bar and Grilled',
#  'Champaign - Urbana Mass Transit District',
#  "Bijoy's Restaurant",
#  'Flight Centre',
#  'Jack in the Box',
#  'Hopdoddy Burger Bar',
#  'La Kabob Lebanese Grill',
#  'Fat Heads Saloon',
#  'Shawarma King',
#  'Britney- Piece of Me',
#  "Ronald's Painting & Home Improvement",
#  'The Keg Steakhouse + Bar',
#  'Tuesday Morning',
#  'Vito’s Pizza & Italian Ristorante',
#  'Starbucks',
#  "Flanny's Bar & Grill",
#  'Sushi on 7',
#  'The Henry',
#  'Squeeze',
#  'To See Roll',
#  'Super Star Nails',
#  'Spiga Ristorante',
#  'D.O.C.G. Enoteca',
#  'Scottsdale Stadium',
#  'Residences at Fountainhead',
#  'Jamba Juice',
#  'The Red Lantern',
#  'Ellis Island Hotel, Casino & Brewery',
#  'Ellis Island Hotel, Casino & Brewery',
#  'Golden Steer Steakhouse',
#  'Sakura Ichiban Restaurant',
#  'Rita B Chuang, MD',
#  'Ocean One Bar and Grille',
#  'Old School Lounge',
#  'Yard House',
#  'Inn Zone',
#  'University Auto Spa',
#  "Fausto's Mexican Grill",
#  'Wallace Espresso',
#  'Abyssinia Restaurant and Cafe',
#  "Predator's Reptile Center",
#  'Zombie Burlesque',
#  "Fellini's Ristorante",
#  "Amalfi's Pasta 'n' Pizza",
#  'Royal Ontario Museum',
#  'Lazeez',
#  'Green Valley Grocery #31',
#  'Richmond Station',
#  'Blue Sea Sushi and Izakaya',
#  'Bella Skin Salon',
#  'Wadaa Street Tacos',
#  'Firehouse Fire Protection',
#  "Raising Cane's",
#  'Mr Nice Guy Games',
#  'Bonefish Grill',
#  'Eldorado Grill',
#  'Aria Sky Suites',
#  'Ahipoki',
#  'The Pho Restaurant',
#  "Glazier's Food Marketplace",
#  'The Optic Zone',
#  'Las Velas',
#  'HomeSpec Inspection Services',
#  "McDonald's",
#  'Industrious Pittsburgh',
#  'Just Around The Corner Pet Sitting & Home Services',
#  "Raising Cane's",
#  'Daisy Cafe & Cupcakery',
#  'The Roomstore',
#  'XS Nightclub',
#  'Smiling Banana Leaf',
#  'Curry Garden',
#  'The Blind Pig Company',
#  'Dutch Bros Coffee',
#  "Pinky's Westside Grill",
#  'Karaoke Q Studio',
#  'Cinebarre - Arboretum 11',
#  'El Cortez Hotel & Casino',
#  'Little Saigon',
#  'Todd English P.U.B.',
#  'The Normal',
#  "Sonny's Tavern",
#  'Tendou Matcha & Dessert',
#  'Maverick Helicopters',
#  'The Reserve at Stone Hollow',
#  "Nino's Pizzeria & Wings",
#  'Galleria Supermarket',
#  'DIRECTV',
#  'The Original Sunrise Cafe',
#  'The Original Sunrise Cafe',
#  'Zaytoon Kabob Bistro',
#  'Carpe Diem! café+pizzeria',
#  'The House Brasserie',
#  'Me Gusta Tacos',
#  'Ramen Sora',
#  'La Belle Nail Spa',
#  'On The Grill',
#  'AMC Fitchburg 18',
#  "Bellisario's Restaurant",
#  'Egg Works',
#  'Imperial Buffet',
#  'Stripburger',
#  'Stripburger',
#  'Sala Thai',
#  'Waffles INCaffeinated',
#  'Showready Landscape',
#  'Hungry Monk',
#  'Monta Chaya',
#  'AllStar Wings & Ribs',
#  'Battle Sports',
#  'Lush Handmade Cosmetics',
#  'I Wok',
#  'Blue Fin Sushi & Roll',
#  'Orbis Caffe',
#  'Pep Boys Auto Service & Tire',
#  'Blueberry Hill Family Restaurant ',
#  'Bath & Body Works',
#  'OpenMat Mixed Martial Arts',
#  'Lexus of Madison',
#  'Palm Beach Tan',
#  'Hillstone Restaurant',
#  'Starbucks',
#  'Freedom Firearms',
#  'Renaissance Charlotte SouthPark Hotel',
#  'Tuvalu Coffehouse & Gallery',
#  'Lidl',
#  'Lidl',
#  'Fresh Madison Market',
#  'Palacio Apartments',
#  'Puritas Hardware & Vacuum',
#  'Rasa',
#  'The Buffet at Bellagio',
#  "Le Coq de l'Est",
#  'The Wokker',
#  'The Jailhouse Taverne',
#  'ARIA Café',
#  'Me Va Me Kitchen Express',
#  "Carole's House Cleaning",
#  'Lago',
#  'Southwest Wildlife Conservation Center',
#  'Fat Cats Gilbert',
#  'Party USA',
#  'Yo & I',
#  'AMC Surprise Pointe 14',
#  'SLS Las Vegas',
#  'Trop-Aquarium',
#  "Maggiano's",
#  'Secret Pizza',
#  'Secret Pizza',
#  'Secret Pizza',
#  'Terrace Restaurants',
#  'barMASA',
#  'Urban Boba Tea House',
#  'Mon Ami Gabi',
#  'OMG Sushi',
#  'Catawba Brewing',
#  'Costa di Mare',
#  'Double Helix Wine & Whiskey Lounge',
#  'The Prime Chinese Restaurant',
#  'Izakaya Cocokala',
#  'The Skeptical Chymist',
#  "Amélie's French Bakery & Café",
#  'Sprinkles Cupcakes',
#  'Pub Bricco',
#  'Juut Salon Spa',
#  'AutoNation Ford Scottsdale',
#  'Frijoles & Frescas Grilled Tacos',
#  "Don't Tell Mama",
#  'Galway Hooker',
#  'Goodyear Auto Service Center',
#  'U.S. Bank',
#  'Maricopa County Fair',
#  'Ginger And Onion Cuisine',
#  'Triple C Brewing Company',
#  'DAVIDsTEA',
#  'Thrifty Car Rental',
#  "Pasqual's",
#  'Maize at the Station',
#  'Bosa Donuts',
#  'Burger Bar',
#  'La Stalla Cucina Rustica',
#  'Cento',
#  'North End Pizza',
#  'North End Pizza',
#  'Mark Kia',
#  'Pei Wei',
#  'Lake Park Family Physicians',
#  'Tax Goddess Business Services',
#  'The Phoenix Ale Brewery Central Kitchen',
#  'The Phoenix Ale Brewery Central Kitchen',
#  'Toro Sushi Bar',
#  'B Spot',
#  'Pizza Hut',
#  'Babbo Italian Eatery',
#  'Pei Wei',
#  'The Rose and Crown',
#  'The Treehouse',
#  'Worth Takeaway',
#  'Worth Takeaway',
#  'Valley Wings',
#  'Volcano Grille',
#  'KaKa All You Can Eat',
#  'Cabo Fish Taco',
#  'Bouchon',
#  'Flaming Kitchen',
#  'Nine Fine Irishmen',
#  'Bonjour Bakery & Deli',
#  'Top Hat Tuxedo',
#  'Swagel Wootton Eye Institute',
#  'Nam Vietnamese Restaurant',
#  "Schlotzsky's",
#  'Realty ONE Group',
#  'Marshalls',
#  'Blair House Suites',
#  'Touhenboku Ramen Restaurant',
#  "Culver's",
#  'Spring Garden Restaurant',
#  'Café Vito',
#  "Dominick's Steakhouse",
#  'Abc the Tavern',
#  'illy Caffè',
#  'Mr Tokyo Japanese Restaurant',
#  'Tattooed Planet',
#  'Fleur by Hubert Keller',
#  "Riliberto's Fresh Mexican Food",
#  'The Buckle',
#  'Pointe Hilton Tapatio Cliffs Resort',
#  'El Norteño',
#  "Hula's Modern Tiki",
#  'Zipps Sports Grill',
#  'Noodle Asia',
#  'Thai Spices',
#  'Paradise Place Jamaican Cuisine',
#  'Redwood Bar and Grill',
#  "Jimmy's Coffee",
#  'Banner Urgent Care',
#  'TCJ Restaurant',
#  'Ryu',
#  'Greens and Proteins',
#  'Lion City Restaurant',
#  'Bristol Truck Rentals',
#  'Emporium Latino',
#  'Golden Nugget',
#  'Canbe Foods',
#  'T-Bird Jewels',
#  'T-Bird Jewels',
#  'American Plumbing and Rooter',
#  'Tacos Mexico',
#  'Food For Thought Deli',
#  'Get Air Las Vegas',
#  'Urban Wellness And Botanicals',
#  'GaNaDaRa',
#  'Feast Buffet',
#  "Rizzo's Spaghetti House",
#  'Starbucks',
#  "Lucky's Pizza",
#  'FEZ',
#  'Yagyu Yakiniku',
#  'Philip Pelusi',
#  'Asi Es Mi Tierra',
#  'Moksha Yoga North York',
#  'El Paso Mexican Grill',
#  'Rice & Company',
#  'Hachi Ramen',
#  'Si Lom Thai Bistro',
#  'Si Lom Thai Bistro',
#  'Larry H. Miller Collision Center',
#  'Ali Baba',
#  'Tropicana Las Vegas',
#  "Carrabba's Italian Grill",
#  'Sumilicious',
#  'Affiliated Pediatric Dentistry & Orthodontics: Scottsdale Shea',
#  'MGM Grand Buffet',
#  'Nazareth Bar',
#  'Little Szechuan',
#  'Scramble A Breakfast Joint',
#  'Colados Coffee & Crepes',
#  'West USA Realty- Mesa',
#  'All Pierogi Kitchen & Euro Market',
#  'South Point Hotel, Casino & Spa',
#  'Casa Santa Fe',
#  'Stetson Hills Animal Hospital',
#  'Istanbul Grill',
#  'Farmer Boys',
#  'Thai St Cafe',
#  'Crown Point Restaurant',
#  'KINKA IZAKAYA ORIGINAL',
#  'Wilshire Pines Apartments by Tonti Properties',
#  'Robinson Realty and Property Management',
#  'Pei Wei',
#  "Eddie V's Prime Seafood",
#  'Postino East',
#  'Uptown Barber Shop',
#  'Enoteca Sociale',
#  'Einstein Bros Bagels',
#  'Kahunaville Island Restaurant',
#  'Pink Taco',
#  'Creating Magic Salon',
#  'La Torretta Ristorante',
#  'Pine Tree Garden Restaurant',
#  'DIRECTV',
#  'Tower of Jewels',
#  'El Frescos Cocina Mexicana',
#  'Yong Kang Street',
#  'Arlecchino Ristorante',
#  'Rockwell Landscape Maintenance',
#  'Aloha Dental',
#  'Verizon',
#  'The Fertility Center of Las Vegas',
#  "Alihan's Mediterranean Cuisine",
#  "Archi's Thai Kitchen",
#  'Le Mont',
#  'The Craft Brasserie & Grille',
#  'The Henry',
#  'Second Story Restaurant & Liquor Bar',
#  'J & J Health Foods',
#  'Nostos',
#  'Pita Kabab Grill',
#  'Sushi Takashi',
#  'Roka Akor - Scottsdale',
#  "Jewel's Bakery and Cafe",
#  'Crave Dessert Bar',
#  "Wade's Discount Muffler & Brakes",
#  'Banh Mi Boys',
#  'Grand Café',
#  'Volkswagen North Scottsdale',
#  '241 Pizza',
#  'Nu Nails',
#  'Desert Diamond West Valley Casino',
#  'Shanghai Shikumen Restaurant',
#  'Trattoria Reggiano',
#  'University Eye Associates',
#  'Nations Fresh Foods',
#  'Reptile Mogul Exotics',
#  'Giligins',
#  'Bosa Donuts',
#  'Madison Sourdough',
#  'Lindstrom Family Auto Wash',
#  'Tapas Papa Frita',
#  'Auto Paradise of Arizona',
#  'Law Offices of Michael A. DeMayo',
#  'Mickie Finnz',
#  'Carpet Discount Warehouse',
#  'Village Pub & Poker',
#  "Uncle Sam's Submarines",
#  'Whist Stove & Spirits',
#  'Hampton Inn Tropicana',
#  'Salon Adikt',
#  "BJ's Restaurant & Brewhouse",
#  "McDonald's",
#  'Saint Sushi Bar',
#  'Buon Gusto Ristorante',
#  "Rubio's",
#  "Magura's - Tropicana",
#  'Rolled Ice Cream',
#  'The Egg & I Cafe',
#  'Hampton Inn and Suites',
#  'Cafe Falafel',
#  'La Salsitas',
#  "David's Hamburgers",
#  "Wendy's",
#  'Arizona Republic',
#  'K1 Speed',
#  'Pita Jungle',
#  'Nevada Eye Physicians',
#  'La Vidorra Spa',
#  'La Michoacana',
#  'Sachi Nails & Lash',
#  'Against the Grain',
#  'Thirsty Parrot',
#  'One Nevada Credit Union',
#  'Garden Court Buffet',
#  'Holtzman Home Improvement',
#  'Gluten Free Creations',
#  'KINTON RAMEN',
#  'Summerlin Pediatric Dentistry',
#  'Samir Pancholi - Cosmetic Surgery of Las Vegas',
#  "Jimmy's Krazy Greek Restaurant",
#  'Phoenicia Cafe',
#  'The Sicilian Butcher',
#  'UFC Gym Las Vegas',
#  'Blanco Tacos And Tequila',
#  'Knight Theater',
#  'Elephant Bar Restaurant',
#  'Comptoir 21',
#  'Western Reserve Hospital',
#  'The Auld Dubliner',
#  "Morton's The Steakhouse",
#  "Adrian's",
#  'Hypnotic Salon & Spa',
#  'Momoyama Sushi',
#  "We'll Carry the Load Movers",
#  "P.F. Chang's",
#  'Shake Shack',
#  'Extreme Fitness',
#  'The Potato Knoll',
#  'Baja Bar & Grill',
#  "TJ's Pizza & Wings",
#  "Genaro's Rotisserie & Grill",
#  'The Great Greek',
#  "Uncle Biff's California Killer Cookies",
#  'The Hobby Bench',
#  'Wolfgang Puck Bar & Grill Las Vegas',
#  'Complete Family Vision Care',
#  'Pool Shop',
#  'Geisha A Go Go',
#  'Cafe 100',
#  'GoodLife Fitness',
#  'Anzios Italian Restaurant',
#  'Honey Pig Korean BBQ',
#  'Algobertos',
#  'Pomo Pizzeria - Phoenix',
#  'Au "Grottens" Cafe & Catering',
#  "Tazza D'oro",
#  "Hawk's Bar & Grill",
#  'Brunswick Zone Mississauga Lanes',
#  'Pink Lotus Nails',
#  'In-N-Out Burger',
#  'Omg Oh My Gyro',
#  "Dave & Buster's",
#  'Greens and Proteins',
#  'See & Be Seen Eyecare',
#  'Gina Corena Law Offices',
#  "Luigi's Pizza",
#  "August Henry's Burger Bar",
#  'Cafe Social',
#  'Cibo Wine Bar',
#  'Aria Ristorante',
#  '1 Epic Nails & Spa',
#  'Sports Book Grill',
#  'The Westin Lake Las Vegas Resort & Spa',
#  "Tokyo Joe's",
#  'Precision Air & Heating',
#  "Coconut's Fish Cafe",
#  'The Buffet',
#  'Treasure Island',
#  'AMS Landscaping',
#  'Blue Ribbon Fried Chicken - Grand Bazaar',
#  'Blue Olive Lounge Ballantyne',
#  'Aliante Dental',
#  'Oyshi Sushi',
#  'Gordon Ramsay Pub & Grill',
#  'Backyard Taco',
#  'EōS Fitness - Las Vegas: Lake Mead/Buffalo',
#  'Real Steemer',
#  'In-N-Out Burger',
#  '808 Sushi',
#  'Wild Wing Cafe',
#  'Anytime Plumbing',
#  'Verona Pizza',
#  'Verona Pizza',
#  'The Barrymore',
#  'Kazu',
#  'Rainforest Café',
#  'Rainforest Café',
#  'Pokitrition - Sushi Burritos & Poke',
#  'Wynn Las Vegas',
#  'Thai To Go',
#  'Makino Sushi & Seafood Buffet',
#  'Customistic',
#  'Loving Hut - Glendale',
#  'PetSmart',
#  "Menchie's Frozen Yogurt",
#  'Albertsons',
#  'Green Mango',
#  "Dunkin' Donuts",
#  'Bar Marco',
#  'Somerset Academy Sky Pointe Campus',
#  'Hilton Garden Inn Phoenix Airport North',
#  'SUSHISAMBA - Las Vegas',
#  'Circus Circus Las Vegas Hotel and Casino',
#  'Mixtape',
#  "Chompie's",
#  'Carolina Ale House',
#  'Family Vetcare of Phoenix',
#  'Super Smog One',
#  'Akane Sushi',
#  'FastMed Urgent Care',
#  "Portofino's Pizza & Pasta",
#  'Curry Twist Restaurant',
#  'Villa Malaysia Lounge & Grill',
#  'Messini Authentic Gyros',
#  'Affordable Tree Service',
#  'Legacy Air',
#  'Oriental Taste Restaurant',
#  'The Pickle Barrel',
#  "Joe's Farm Grill",
#  'Montecassino Hotel',
#  'Crust Chandler-Simply Italian',
#  'Style by Maciel',
#  "Cocolini's",
#  'Oyster Bar',
#  "Bahama Buck's",
#  'Vapiano',
#  'Allergy Asthma Clinic',
#  'Donut Hut',
#  'Red Lobster',
#  "PaPa Chang's",
#  'Rudy\'s "Country Store" and Bar-B-Q',
#  "D'Angelo's Italian Ristorante",
#  'LV Photo',
#  'Fiamma Italian Kitchen',
#  'Timo Wine Bar',
#  "McKoy's Smokehouse & Saloon",
#  'The Goodwich',
#  "Kettlemuck's Toy Shoppe",
#  'Rotech Healthcare',
#  'Shampoo Ink',
#  "Mineo's Pizza House",
#  "Khoury's Mediterranean Restaurant",
#  'Red 8',
#  'Taco Bell',
#  'Whole Foods Market',
#  'Rock & Roll Hall of Fame',
#  'Francis & Sons Car Wash',
#  'Choko-Mocko',
#  'Muesliikon Green Cafe',
#  'Boondocks Patio & Grill',
#  'Mango Rabbit',
#  'Heritage Park',
#  'MAMAOH',
#  'Crêpe Expectations',
#  'Mill Street Brew Pub',
#  'Bellagio Hotel',
#  'Neuromuscular Therapy',
#  'Pizza Lotto',
#  'Crocker Park',
#  'Poukei',
#  "Big Jimmy's Pizza",
#  'KJ Kitchen',
#  'Glo Medspa',
#  "People's Indian Restaurant",
#  'Merci French Cafe & Patisserie',
#  'Discount Sprinkler And Drip Repair',
#  'WHASN Meadows',
#  '99 Pub and Grill',
#  'Jodys Sundays & Deli',
#  'Sleepy Poet Antique Mall',
#  'Mantelier',
#  "Michael A's Restaurant & Lounge",
#  "Macayo's Mexican Table",
#  'Best Nails',
#  'Starbucks',
#  'ACE Rent A Car',
#  'The Dakota Tavern',
#  'Sweet Poké',
#  'La Grande Orange Pizzeria',
#  "AJ's Fine Foods",
#  "VinciTorio's",
#  'Salad and Go',
#  'Bixels Salon and Spa Studio',
#  'Sidestreet Pho and Grill',
#  'Pho Metro',
#  'Skin Therapy of Charlotte',
#  "Ace's Barbershop and Family Salon",
#  'Vip Nails',
#  "Fatty Daddy's",
#  'Hanabi Japanese Restaurant']
